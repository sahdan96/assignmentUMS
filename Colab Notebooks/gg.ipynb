# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('https://raw.githubusercontent.com/sahdan96/randomforest/main/train_2v.csv')
# train_data = pd.read_csv('D:\\UMS\\Semester 7\\FYP2\\Extend_build\\train.csv')

# %%
train_data.shape
# Out:
# (43400, 12)

# %%
train_data.head()
# Out:
#       id  gender   age  ...   bmi   smoking_status stroke
# 0  30669    Male   3.0  ...  18.0              NaN      0
# 1  30468    Male  58.0  ...  39.2     never smoked      0
# 2  16523  Female   8.0  ...  17.6              NaN      0
# 3  56543  Female  70.0  ...  35.9  formerly smoked      0
# 4  46136    Male  14.0  ...  19.1              NaN      0
#
# [5 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
train_data['gender']=label.fit_transform(train_data['gender'])
train_data['ever_married']=label.fit_transform(train_data['ever_married'])
train_data['work_type']=label.fit_transform(train_data['work_type'])
train_data['Residence_type']=label.fit_transform(train_data['Residence_type'])
train_data['smoking_status']=label.fit_transform(train_data['smoking_status'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0e0cc977a31f> in <module>()
#       3 train_data['work_type']=label.fit_transform(train_data['work_type'])
#       4 train_data['Residence_type']=label.fit_transform(train_data['Residence_type'])
# ----> 5 train_data['smoking_status']=label.fit_transform(train_data['smoking_status'])
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     250         """
#     251         y = column_or_1d(y, warn=True)
# --> 252         self.classes_, y = _encode(y, encode=True)
#     253         return y
#     254
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in _encode(values, uniques, encode, check_unknown)
#     112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
# --> 114             raise TypeError("argument must be a string or number")
#     115         return res
#     116     else:
#
# TypeError: argument must be a string or number

# %%
train_data.head()

# %%
from sklearn.model_selection import train_test_split

# %%
x = train_data.loc[:,train_data.columns!='stroke']
y = train_data['stroke']

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ran = RandomForestClassifier(n_estimators = 10, random_state= 0)

# %%
ran.fit(X_train, y_train)

# %%
pred = ran.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, auc,roc_auc_score, precision_score, recall_score

# %%
accuracy_score(y_test, pred)

# %%
label1 = LabelEncoder()
test_data = pd.read_csv('https://raw.githubusercontent.com/sahdan96/randomforest/main/test_2v.csv')

# %%
test_data.head()

# %%
test_data.isnull().sum()

# %%
test_data.isnull().sum()

# %%
test_data['bmi'] = train_data['bmi'].fillna(test_data['bmi'].mean())
test_data.dropna(axis=0, inplace=True)

# %%
test_data['gender']=label.fit_transform(test_data['gender'])
test_data['ever_married']=label.fit_transform(test_data['ever_married'])
test_data['work_type']=label.fit_transform(test_data['work_type'])
test_data['Residence_type']=label.fit_transform(test_data['Residence_type'])
test_data['smoking_status']=label.fit_transform(test_data['smoking_status'])

# %%
pred2 = ran.predict([[10434,0,69,0,0,0,1,1,94.39,22.8,1]])

# %%
pred2
